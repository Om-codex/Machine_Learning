# %%
from sklearn.datasets import load_iris
import numpy as np
from kmeans import KMeans

# %%
iris = load_iris()
X = iris.data
y = iris.target

# %%
print(X.shape)
print(y.shape)
# Out:
# (150, 4)
# (150,)

# %%
km = KMeans(n_clusters=3,max_iter = 100)
clusters = km.fit_predict(X)
wcss_value = km.calculate_wcss(X,clusters)

# %%
print("WCSS Value:",wcss_value)
print("Centroids:",km.centroids)
# Out:
# WCSS Value: 78.851441426146
# Centroids: [[5.9016129  2.7483871  4.39354839 1.43387097]
#  [6.85       3.07368421 5.74210526 2.07105263]
#  [5.006      3.428      1.462      0.246     ]]

# %%
from sklearn.metrics import adjusted_rand_score
ari = adjusted_rand_score(y, clusters)
print("Adjusted Rand Index (similarity to actual labels):", ari)
# Out:
# Adjusted Rand Index (similarity to actual labels): 0.7302382722834697

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Reducing dimensions for visualization
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

plt.scatter(X_pca[:, 0], X_pca[:, 1], c=clusters, cmap='rainbow', s=50)
plt.title("K-Means Clustering on Iris Dataset")
plt.xlabel("PCA 1")
plt.ylabel("PCA 2")
plt.show()
